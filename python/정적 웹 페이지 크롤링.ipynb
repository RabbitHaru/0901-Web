# %%
from bs4 import BeautifulSoup
html = '<h1 id="title">한빛출판네트워크</h1><div class="top"><ul class="menu"><li><a href="http://www.hanbit.co.kr/member/login.html" class="login">로그인</a></li></ul><ul class="brand"><li><a href="http://www.hanbit.co.kr/member/media">한빛미디어</li><li><a href="http://www.hanbit.co.kr/member/academy">한빛아카데미</li></ul></div>'
soup = BeautifulSoup(html, 'html.parser')
print(soup)
print(soup.h1)
print(soup.div)
print(soup.a)
print(soup.ul)
print(soup.li)
# find_all("속성") : 모든 속성에 맞는 태그를 찾아 리스트로 반환
liTag = soup.find_all("a")
for i in liTag:
    print(i)
# find("속성") : 속성을 이용한 특정 태그를 찾아 반환
login = soup.find('a', attrs={'class':'login'})
print(login)
id = soup.find(attrs={'id':'title'})
print(id)
# select("css선택자") : css설정시 사용하는 선택자를 이용하여 찾는 함수
li_list = soup.select("div>ul.brand>li")
for li in li_list:
    print(li)
# Out:
# <h1 id="title">한빛출판네트워크</h1><div class="top"><ul class="menu"><li><a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a></li></ul><ul class="brand"><li><a href="http://www.hanbit.co.kr/member/media">한빛미디어</a></li><li><a href="http://www.hanbit.co.kr/member/academy">한빛아카데미</a></li></ul></div>
# <h1 id="title">한빛출판네트워크</h1>
# <div class="top"><ul class="menu"><li><a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a></li></ul><ul class="brand"><li><a href="http://www.hanbit.co.kr/member/media">한빛미디어</a></li><li><a href="http://www.hanbit.co.kr/member/academy">한빛아카데미</a></li></ul></div>
# <a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a>
# <ul class="menu"><li><a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a></li></ul>
# <li><a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a></li>
# <a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a>
# <a href="http://www.hanbit.co.kr/member/media">한빛미디어</a>
# <a href="http://www.hanbit.co.kr/member/academy">한빛아카데미</a>
# <a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a>
# <h1 id="title">한빛출판네트워크</h1>
# <li><a href="http://www.hanbit.co.kr/member/media">한빛미디어</a></li>
# <li><a href="http://www.hanbit.co.kr/member/academy">한빛아카데미</a></li>

# %%
from bs4 import BeautifulSoup
html = '<h1 id="title">한빛출판네트워크</h1><div class="top"><ul class="menu"><li><a href="http://www.hanbit.co.kr/member/login.html" class="login">로그인</a></li></ul><ul class="brand"><li><a href="http://www.hanbit.co.kr/member/media">한빛미디어</li><li><a href="http://www.hanbit.co.kr/member/academy">한빛아카데미</li></ul></div>'
soup = BeautifulSoup(html, 'html.parser')
aTag = soup.a
print(aTag)
# attrs : 속성들을 딕셔너리 형식으로 저장하는 변수
print(aTag.attrs)
# 딕셔너리에서 데이터를 꺼내는 방식으로 속성의 값을 출력할 수 있음
print(aTag['class'])
print(aTag['href'])
# Out:
# <a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a>
# {'href': 'http://www.hanbit.co.kr/member/login.html', 'class': ['login']}
# ['login']
# http://www.hanbit.co.kr/member/login.html

# %%
# 필요한 라이브러리 추가
from bs4 import BeautifulSoup
import urllib.request
# 결과를 저장할 변수 선언
result = []
# 몇 페이지까지 데이터를 받아올지 설정하는 반복문
for page in range(1,46+1):
    # 데이터를 가지고올 페이지의 url 설정
    # pageNo가 1이면 1페이지, 2면 2페이지
    hollys_url = f'https://www.hollys.co.kr/store/korea/korStore2.do?pageNo={page}&sido=&gugun=&store='
    print(hollys_url)
    # url을 이용하여 실제 페이지의 html 코드를 변수 저장
    html = urllib.request.urlopen(hollys_url)
    # 각각의 html안의 태그를 검색할 수 있도록 파싱진행
    soupHollys = BeautifulSoup(html,'html.parser')
    # 매장정보가 들어있는 tbody 태그를 변수에 저장
    tag_tbody = soupHollys.find('tbody')
    # 열하나에 매장 하나가 들어있기 때문에 열을 기준으로 반복문 실행
    for store in tag_tbody.find_all("tr"):
        # tr태그의 문자열이 3글자 보다 작으면 반복문 종료
        if len(store) <= 3 :
            break
        # 각각의 데이터가 들어있는 td태그를 저장
        store_td = store.find_all('td')
        store_name = store_td[1].string # 매장명
        store_sido = store_td[0].string # 지역
        store_address = store_td[3].string # 주소
        store_phone = store_td[5].string # 전화번호
        store_flag = store_td[2].string # 현황
        # 매장정보를 list에 저장
        result.append([store_name]+[store_sido]+[store_address]+[store_phone])
for i in result:
    print(i)
import pandas as pd
# 리스트 자료형의 데이터를 판다스에서 사용하는 형식(테이블)으로 변경
hollys_tbl = pd.DataFrame(result, columns=('store','sido-gu','address','phone'))
# csv로 저장
# to_csv("파일경로", encoding="인코딩 형식", mode="파일모드r,w,a", index=번호출력여부)
hollys_tbl.to_csv("hollys.csv", encoding="utf-8", mode="w", index=True)
# Out:
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=1&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=2&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=3&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=4&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=5&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=6&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=7&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=8&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=9&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=10&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=11&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=12&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=13&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=14&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=15&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=16&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=17&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=18&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=19&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=20&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=21&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=22&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=23&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=24&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=25&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=26&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=27&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=28&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=29&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=30&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=31&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=32&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=33&sido=&gugun=&store=
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7472\247328998.py in <module>
#      11     print(hollys_url)
#      12     # url을 이용하여 실제 페이지의 html 코드를 변수 저장
# ---> 13     html = urllib.request.urlopen(hollys_url)
#      14     # 각각의 html안의 태그를 검색할 수 있도록 파싱진행
#      15     soupHollys = BeautifulSoup(html,'html.parser')
#
# c:\Users\it\AppData\Local\Programs\Python\Python37\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# c:\Users\it\AppData\Local\Programs\Python\Python37\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# c:\Users\it\AppData\Local\Programs\Python\Python37\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# c:\Users\it\AppData\Local\Programs\Python\Python37\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# c:\Users\it\AppData\Local\Programs\Python\Python37\lib\urllib\request.py in https_open(self, req)
#    1391         def https_open(self, req):
#    1392             return self.do_open(http.client.HTTPSConnection, req,
# -> 1393                 context=self._context, check_hostname=self._check_hostname)
#    1394
#    1395         https_request = AbstractHTTPHandler.do_request_
#
# c:\Users\it\AppData\Local\Programs\Python\Python37\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1351             except OSError as err: # timeout error
#    1352                 raise URLError(err)
# -> 1353             r = h.getresponse()
#    1354         except:
#    1355             h.close()
#
# c:\Users\it\AppData\Local\Programs\Python\Python37\lib\http\client.py in getresponse(self)
#    1367         try:
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#    1371                 self.close()
#
# c:\Users\it\AppData\Local\Programs\Python\Python37\lib\http\client.py in begin(self)
#     308         # read until we get a non-100 response
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#     312                 break
#
# c:\Users\it\AppData\Local\Programs\Python\Python37\lib\http\client.py in _read_status(self)
#     269
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#     273             raise LineTooLong("status line")
#
# c:\Users\it\AppData\Local\Programs\Python\Python37\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# c:\Users\it\AppData\Local\Programs\Python\Python37\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# c:\Users\it\AppData\Local\Programs\Python\Python37\lib\ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
